# %%
import pandas as pd

# %%
pd.set_option('max_columns', None)
#pd.reset_option('max_columns')

# %%
df_flights = pd.read_csv('flights_data.csv')
# Out:
# F:\Anaconda\envs\lhl\lib\site-packages\IPython\core\interactiveshell.py:3170: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Create 'state' column
df_flights['state'] = df_flights['origin_city_name'].str[-2:]

# Set delay nulls to zero (zero minutes of delay instead of null)
df_flights[['arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay']] = df_flights[['arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay']].fillna(value=0)

# Format fl_date column as a date
df_flights['fl_date'] = pd.to_datetime(df_flights['fl_date'])

# Create fl_month column
df_flights['fl_day'] = pd.DatetimeIndex(df_flights['fl_date']).day

# Get and apply mean flight delay values
df_delay_means = df_flights.groupby('fl_day').mean()[['arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay']].reset_index()
df_flights['daily_arr_delay_mean'] = df_flights.apply(lambda row: df_delay_means['arr_delay'][row['fl_day']-1], axis=1)
df_flights['daily_carrier_delay_mean'] = df_flights.apply(lambda row: df_delay_means['carrier_delay'][row['fl_day']-1], axis=1)
df_flights['daily_weather_delay_mean'] = df_flights.apply(lambda row: df_delay_means['weather_delay'][row['fl_day']-1], axis=1)
df_flights['daily_nas_delay_mean'] = df_flights.apply(lambda row: df_delay_means['nas_delay'][row['fl_day']-1], axis=1)
df_flights['daily_security_delay_mean'] = df_flights.apply(lambda row: df_delay_means['security_delay'][row['fl_day']-1], axis=1)
df_flights['daily_late_aircraft_delay_mean'] = df_flights.apply(lambda row: df_delay_means['late_aircraft_delay'][row['fl_day']-1], axis=1)

# %%
# Drop unneccessary columns (this should be the final step)
df_flights = df_flights.drop(columns=['carrier_delay', 'weather_delay', 'nas_delay', 'security_delay', 'late_aircraft_delay', 'no_name'])

# %%
df_flights
# Out:
#           fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0      2018-01-01                 DL       DL_CODESHARE          DL
# 1      2018-01-01                 DL       DL_CODESHARE          DL
# 2      2018-01-01                 DL       DL_CODESHARE          DL
# 3      2018-01-01                 DL       DL_CODESHARE          DL
# 4      2018-01-01                 DL       DL_CODESHARE          DL
# ...           ...                ...                ...         ...
# 321093 2019-01-08                 UA       UA_CODESHARE          UA
# 321094 2019-01-08                 UA       UA_CODESHARE          UA
# 321095 2019-01-08                 UA       UA_CODESHARE          UA
# 321096 2019-01-08                 UA       UA_CODESHARE          UA
# 321097 2019-01-08                 UA       UA_CODESHARE          UA
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                     3468                9E   N292PQ               3468
# ...
